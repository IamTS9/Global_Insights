# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/tanish/Desktop/DS_ML/DATA/CIA_Country_Facts.csv')

# %%
df.head()
# Out:
#           Country                               Region  Population  \
# 0     Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1         Albania  EASTERN EUROPE                          3581655
# 2         Algeria  NORTHERN AFRICA                        32930091
# 3  American Samoa  OCEANIA                                   57794
# 4         Andorra  WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
df.shape
# Out:
# (227, 20)

# %%
df.describe().transpose()
# Out:
#                                     count          mean           std  \
# Population                          227.0  2.874028e+07  1.178913e+08
# Area (sq. mi.)                      227.0  5.982270e+05  1.790282e+06
# Pop. Density (per sq. mi.)          227.0  3.790471e+02  1.660186e+03
# Coastline (coast/area ratio)        227.0  2.116533e+01  7.228686e+01
# Net migration                       224.0  3.812500e-02  4.889269e+00
# Infant mortality (per 1000 births)  224.0  3.550696e+01  3.538990e+01
# GDP ($ per capita)                  226.0  9.689823e+03  1.004914e+04
# Literacy (%)                        209.0  8.283828e+01  1.972217e+01
# Phones (per 1000)                   223.0  2.360614e+02  2.279918e+02
# Arable (%)                          225.0  1.379711e+01  1.304040e+01
# Crops (%)                           225.0  4.564222e+00  8.361470e+00
# Other (%)                           225.0  8.163831e+01  1.614083e+01
# ...

# %%
df.isnull().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
df[df['Agriculture'].isnull()]
# Out:
#                   Country                               Region  Population  \
# 3          American Samoa  OCEANIA                                   57794
# 4                 Andorra  WESTERN EUROPE                            71201
# 78              Gibraltar  WESTERN EUROPE                            27928
# 80              Greenland  NORTHERN AMERICA                          56361
# 83                   Guam  OCEANIA                                  171019
# 134               Mayotte  SUB-SAHARAN AFRICA                       201234
# 140            Montserrat              LATIN AMER. & CARIB            9439
# 144                 Nauru  OCEANIA                                   13287
# 153    N. Mariana Islands  OCEANIA                                   82459
# 171          Saint Helena  SUB-SAHARAN AFRICA                         7502
# 174  St Pierre & Miquelon  NORTHERN AMERICA                           7026
# ...

# %%
# We see that agriculture is null for most small islands where we can mark other features as 0 as well

# %%
df[df['Agriculture'].isnull()] = df[df['Agriculture'].isnull()].fillna(0)

# %%
df.isnull().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          1
# Infant mortality (per 1000 births)     1
# GDP ($ per capita)                     0
# Literacy (%)                          13
# Phones (per 1000)                      2
# Arable (%)                             1
# Crops (%)                              1
# Other (%)                              1
# Climate                               18
# Birthrate                              1
# Deathrate                              2
# Agriculture                            0
# Industry                               1
# Service                                1
# dtype: int64

# %%
df[df['Climate'].isnull()]
# Out:
#            Country                               Region  Population  \
# 5           Angola  SUB-SAHARAN AFRICA                     12127071
# 36          Canada  NORTHERN AMERICA                       33098932
# 50         Croatia  EASTERN EUROPE                          4494749
# 66   Faroe Islands  WESTERN EUROPE                            47246
# 101          Italy  WESTERN EUROPE                         58133509
# 115        Lebanon  NEAR EAST                               3874050
# 118          Libya  NORTHERN AFRICA                         5900754
# 120      Lithuania  BALTICS                                 3585906
# 121     Luxembourg  WESTERN EUROPE                           474413
# 129          Malta  WESTERN EUROPE                           400214
# 137        Moldova                 C.W. OF IND. STATES      4466706
# 138         Monaco  WESTERN EUROPE                            32543
# 141        Morocco  NORTHERN AFRICA                        33241259
# ...

# %%
df['Climate'] = df['Climate'].fillna(df.groupby("Region")['Climate'].transform('mean'))

# %%
df[df['Literacy (%)'].isnull()]
# Out:
#                   Country                               Region  Population  \
# 25   Bosnia & Herzegovina  EASTERN EUROPE                          4498976
# 66          Faroe Islands  WESTERN EUROPE                            47246
# 74             Gaza Strip  NEAR EAST                               1428757
# 85               Guernsey  WESTERN EUROPE                            65409
# 99            Isle of Man  WESTERN EUROPE                            75441
# 104                Jersey  WESTERN EUROPE                            91084
# 108              Kiribati  OCEANIA                                  105432
# 123             Macedonia  EASTERN EUROPE                          2050554
# 185              Slovakia  EASTERN EUROPE                          5439448
# 187       Solomon Islands  OCEANIA                                  552438
# 209                Tuvalu  OCEANIA                                   11810
# ...

# %%
df['Literacy (%)'] = df['Literacy (%)'].fillna(df.groupby("Region")['Literacy (%)'].transform('mean'))

# %%
df.isnull().sum()
# Out:
# Country                               0
# Region                                0
# Population                            0
# Area (sq. mi.)                        0
# Pop. Density (per sq. mi.)            0
# Coastline (coast/area ratio)          0
# Net migration                         1
# Infant mortality (per 1000 births)    1
# GDP ($ per capita)                    0
# Literacy (%)                          0
# Phones (per 1000)                     2
# Arable (%)                            1
# Crops (%)                             1
# Other (%)                             1
# Climate                               0
# Birthrate                             1
# Deathrate                             2
# Agriculture                           0
# Industry                              1
# Service                               1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Country                               0
# Region                                0
# Population                            0
# Area (sq. mi.)                        0
# Pop. Density (per sq. mi.)            0
# Coastline (coast/area ratio)          0
# Net migration                         0
# Infant mortality (per 1000 births)    0
# GDP ($ per capita)                    0
# Literacy (%)                          0
# Phones (per 1000)                     0
# Arable (%)                            0
# Crops (%)                             0
# Other (%)                             0
# Climate                               0
# Birthrate                             0
# Deathrate                             0
# Agriculture                           0
# Industry                              0
# Service                               0
# dtype: int64

# %%
df.shape
# Out:
# (221, 20)

# %%
df['Region'].unique()
# Out:
# array(['ASIA (EX. NEAR EAST)         ',
#        'EASTERN EUROPE                     ',
#        'NORTHERN AFRICA                    ',
#        'OCEANIA                            ',
#        'WESTERN EUROPE                     ',
#        'SUB-SAHARAN AFRICA                 ', 'LATIN AMER. & CARIB    ',
#        'C.W. OF IND. STATES ', 'NEAR EAST                          ',
#        'NORTHERN AMERICA                   ',
#        'BALTICS                            '], dtype=object)

# %%
plt.figure(figsize=(6, 4), dpi=150)
sorted_df = df.sort_values(by="Population", ascending=False)

# Now, plot the sorted DataFrame
sns.barplot(x='Region', y="Population", data=sorted_df)
plt.xticks(rotation=90);

# %%
top_10_area = df.sort_values(by="Area (sq. mi.)", ascending=False)[:10]
plt.figure(figsize=(6, 4), dpi=150)
sns.barplot(x='Country', y="Area (sq. mi.)", data=top_10_area)
plt.xticks(rotation=90);

# %%
sns.scatterplot(x=df['GDP ($ per capita)'], y=df['Phones (per 1000)'], hue=df['Region'])
plt.legend(loc=(1.05, 0.5))

# %%
df[df['GDP ($ per capita)'] > 50000]
# Out:
#         Country                               Region  Population  \
# 121  Luxembourg  WESTERN EUROPE                           474413
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 121            2586                       183.5                           0.0
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 121           8.97                                4.81             55100.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 121         100.0              515.4       23.28        0.4      76.32
#
#       Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# 121  2.826087      11.94       8.41         0.01      0.13     0.86

# %%
sns.scatterplot(x=df['Infant mortality (per 1000 births)'], y=df['Birthrate'], hue=df['Region'])
plt.legend(loc=(1.05, 0.5))

# %%
df[df['Infant mortality (per 1000 births)']>150]
# Out:
#        Country                               Region  Population  \
# 0  Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 5       Angola  SUB-SAHARAN AFRICA                     12127071
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 5         1246700                         9.7                          0.13
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0          23.06                              163.07               700.0
# 5           0.00                              191.19              1900.0
#
#    Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 0          36.0                3.2       12.13       0.22      87.65
# 5          42.0                7.8        2.41       0.24      97.35
#
#     Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# ...

# %%
sns.scatterplot(x=df['Crops (%)'], y=df['Arable (%)'], hue=df['Region'])
plt.legend(loc=(1.05, 0.5));

# %%
sns.scatterplot(x=df['Pop. Density (per sq. mi.)'], y=df['Population'], hue=df['Region'])
plt.legend(loc=(1.05, 0.5));

# %%
df[df['Pop. Density (per sq. mi.)'] >= 2000]
# Out:
#         Country                               Region  Population  \
# 74   Gaza Strip  NEAR EAST                               1428757
# 78    Gibraltar  WESTERN EUROPE                            27928
# 91    Hong Kong        ASIA (EX. NEAR EAST)              6940432
# 122       Macau        ASIA (EX. NEAR EAST)               453125
# 184   Singapore        ASIA (EX. NEAR EAST)              4492150
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 74              360                      3968.8                         11.11
# 78                7                      3989.7                        171.43
# 91             1092                      6355.7                         67.12
# 122              28                     16183.0                        146.43
# 184             693                      6482.2                         27.85
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
sns.heatmap(df.corr(), cmap = 'Set3')
# Out:
# /var/folders/cr/pmdjvjnx1k58t2hd_rw1_rtc0000gn/T/ipykernel_46548/784993275.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <Axes: >

# %%
sns.clustermap(df.corr(), cmap = 'Set3')
# Out:
# /var/folders/cr/pmdjvjnx1k58t2hd_rw1_rtc0000gn/T/ipykernel_46548/2634097098.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
X = df.drop("Country", axis=1)

# %%
X = pd.get_dummies(X)

# %%
X
# Out:
#      Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 0      31056997          647500                        48.0
# 1       3581655           28748                       124.6
# 2      32930091         2381740                        13.8
# 3         57794             199                       290.4
# 4         71201             468                       152.1
# ..          ...             ...                         ...
# 222     2460492            5860                       419.9
# 223      273008          266000                         1.0
# 224    21456188          527970                        40.6
# 225    11502010          752614                        15.3
# 226    12236805          390580                        31.3
#
#      Coastline (coast/area ratio)  Net migration  \
# 0                            0.00          23.06
# 1                            1.26          -4.93
# 2                            0.04          -0.39
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)

# %%
sum_sq_dis = []

for clusters in range(2, 30):
    kmeans = KMeans(n_clusters=clusters, n_init='auto')
    kmeans.fit(scaled_X)
    sum_sq_dis.append(kmeans.inertia_)

# %%
plt.plot(range(2, 30), sum_sq_dis, '--o', color = 'g')

# %%
model = KMeans(n_clusters=6, n_init='auto')
model.fit(scaled_X)
# Out:
# KMeans(n_clusters=6, n_init='auto')

# %%
X['Clusters'] = model.labels_

# %%
df_imp = pd.DataFrame(X.corr()['Clusters'].sort_values()[:-1])

# %%
df_imp
# Out:
#                                             Clusters
# Region_LATIN AMER. & CARIB                 -0.532244
# Birthrate                                  -0.355064
# Infant mortality (per 1000 births)         -0.347183
# Region_SUB-SAHARAN AFRICA                  -0.297192
# Agriculture                                -0.255139
# Region_C.W. OF IND. STATES                 -0.152928
# Deathrate                                  -0.150739
# Industry                                   -0.140850
# Region_BALTICS                             -0.130958
# Other (%)                                  -0.067182
# Region_NORTHERN AFRICA                      0.005204
# Region_NEAR EAST                            0.008407
# Population                                  0.023498
# Area (sq. mi.)                              0.031965
# Arable (%)                                  0.052268
# Region_ASIA (EX. NEAR EAST)                 0.059188
# Crops (%)                                   0.084206
# ...

# %%
plt.figure(figsize=(6, 4), dpi=200)
sns.barplot(x=df_imp.index, y=df_imp['Clusters'])
plt.xticks(rotation=90);

# %%
iso_codes = pd.read_csv('/Users/tanish/Desktop/PyProjects/Country_Clustering /country_iso_codes.csv')
iso_map = iso_codes.set_index('Country')['ISO Code'].to_dict()

# %%
df['ISO Code'] = df['Country'].map(iso_map)

# %%
df['Cluster'] = model.labels_

# %%
import plotly.express as px

fig = px.choropleth(df, locations="ISO Code",
                    color="Cluster", # lifeExp is a column of gapminder
                    hover_name="Country", # column to add to hover information)
                   )
fig.show()
# Out:
# <div>                            <div id="e4ac513a-e738-443d-a0e0-63e05be345d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4ac513a-e738-443d-a0e0-63e05be345d1")) {                    Plotly.newPlot(                        "e4ac513a-e738-443d-a0e0-63e05be345d1",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>ISO Code=%{location}<br>Cluster=%{z}<extra></extra>","hovertext":["Afghanistan","Albania","Algeria","American Samoa","Andorra","Angola","Anguilla","Antigua & Barbuda","Argentina","Armenia","Aruba","Australia","Austria","Azerbaijan","Bahamas, The","Bahrain","Bangladesh","Barbados","Belarus","Belgium","Belize","Benin","Bermuda","Bhutan","Bolivia","Bosnia & Herzegovina","Botswana","Braz
# ...

# %%
from IPython.display import Image
Image(filename='Output.png', width=1000, height=1000)
